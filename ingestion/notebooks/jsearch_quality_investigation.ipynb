# %%
import os
import json
import pandas as pd
import snowflake.connector
from dotenv import load_dotenv

load_dotenv()

conn = snowflake.connector.connect(
    account=os.getenv("SNOWFLAKE_ACCOUNT"),
    user=os.getenv("SNOWFLAKE_USER"),
    password=os.getenv("SNOWFLAKE_PASSWORD"),
    role=os.getenv("SNOWFLAKE_ROLE"),
    warehouse=os.getenv("SNOWFLAKE_WAREHOUSE"),
    database="RAW",
)

def run_query(sql):
    cur = conn.cursor()
    cur.execute(sql)
    rows = cur.fetchall()
    cols = [desc[0] for desc in cur.description]
    cur.close()
    return pd.DataFrame(rows, columns=cols)

print("Connected!")
# Out:
# Connected!

# %%
jsearch_publishers = run_query("""
    SELECT 
        RAW_PAYLOAD:job_publisher::STRING as publisher,
        COUNT(*) as cnt,
        ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (), 1) as pct
    FROM RAW.JSEARCH.SRC_POSTINGS
    GROUP BY 1
    ORDER BY cnt DESC
""")
display(jsearch_publishers)
# Out:
#                                             PUBLISHER  CNT   PCT
# 0                                            LinkedIn   93  27.9
# 1                                          Talent.com   81  24.3
# 2                                          Learn4Good   44  13.2
# 3                                            JobLeads   20   6.0
# 4                                               BeBee   12   3.6
# 5                                            WhatJobs   11   3.3
# 6                                            Jobilize    7   2.1
# 7                                        ZipRecruiter    7   2.1
# 8                                        Built In NYC    5   1.5
# 9                                             Monster    4   1.2
# 10                                               Dice    3   0.9
# 11                                    Point72 Careers    3   0.9
# 12                                             Indeed    3   0.9
# 13                                             Jooble    3   0.9
# 14                                         TSA Hiring    2   0.6
# 15                                         Mastercard    2   0.6
# 16                                             Adzuna    2   0.6
# 17                                            Ladders    2   0.6
# 18                                           Snagajob    2   0.6
# 19                             Institute Of Data Jobs    2   0.6
# 20                                 Tech Engineer Jobs    2   0.6
# 21                                          Talentify    1   0.3
# 22        Weill Cornell Medicine - Cornell University    1   0.3
# 23                                        Recruit.net    1   0.3
# 24                              Careers In Government    1   0.3
# 25                                     Energy Jobline    1   0.3
# 26                                    Jobs - Deloitte    1   0.3
# 27                                    Netflix Careers    1   0.3
# 28                                         NYCVFX.com    1   0.3
# 29                               The D. E. Shaw Group    1   0.3
# 30                                      Kohls Careers    1   0.3
# 31                   Bayview Asset Management Careers    1   0.3
# 32                       United States Jobs Expertini    1   0.3
# 33                                               Teal    1   0.3
# 34                              Welcome To The Jungle    1   0.3
# 35                                            Sign In    1   0.3
# 36                                   Barclays Careers    1   0.3
# 37                                     Allied-IT Jobs    1   0.3
# 38                                Trigyn Technologies    1   0.3
# 39                                 Resume-Library.com    1   0.3
# 40  Higher Education Recruitment Consortium (HERC)...    1   0.3
# 41                                  EFinancialCareers    1   0.3
# 42              Danaher Careers - Danaher Corporation    1   0.3
# 43                                             Trigyn    1   0.3
